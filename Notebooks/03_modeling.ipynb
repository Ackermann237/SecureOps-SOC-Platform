# %%
# si tu travailles dans le même kernel
intrusion_df = intrusion_df.copy()

intrusion_df.to_csv("data/processed/intrusion_features.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # si tu travailles dans le même kernel
# ----> 2 intrusion_df = intrusion_df.copy()
#       4 intrusion_df.to_csv("data/processed/intrusion_features.csv", index=False)
#
# NameError: name 'intrusion_df' is not defined
